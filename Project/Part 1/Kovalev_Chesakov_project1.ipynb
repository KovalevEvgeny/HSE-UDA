# %% [markdown]
# # 1. Описание задачи

# %% [markdown]
# В рамках предмета «Анализ неструктурированных данных» с целью получения практических навыков работы с текстами и API был выполнен проект по составлению собственного корпуса технических новостей с сайта HackerNews (https://news.ycombinator.com/). Это веб-агрегатор, где пользователь может опубликовать новостной пост, задать интересующий вопрос (ASK HN), поделиться чем-то с комьюнити (Show HN) или откликнуться на какую-либо из предложенных в отдельном разделе сайта вакансий.
#
# Согласно техническому заданию, необходимо было получить посты за последние полгода вместе с информацией о них (комментарии, число лайков, дата публикации и ссылки на внешние ресурсы), пройти по всем найденным в полученных постах ссылкам с последующим сохранением страниц в виде текстовых сообщений, выделить в них упоминающие определенный бренд и сделать краткий анализ извлеченных данных.

# %%
import datetime
import numpy as np
import pandas as pd
import requests
import re
import time
from bs4 import BeautifulSoup
from hackernews import HackerNews
from nltk import FreqDist
from nltk.corpus import stopwords
from readability import Document
from urllib.parse import urlparse

stop_words = stopwords.words('english')

# %% [markdown]
# # 2. Сбор последних постов

# %% [markdown]
# Для работы с HackerNews использовался найденный враппер для официального API рассматриваемого ресурса (https://github.com/HackerNews/API). Он доступен по следующей ссылке: https://github.com/avinassh/haxor.
#
# С его помощью были извлечены новейшие посты, их id, названия, даты публикации, содержащиеся в них внешние ссылки, комментарии и число лайков.

# %%
hn = HackerNews()

# %% [markdown]
# Из описания официального API HackerNews:
#
# > Up to 500 top and new stories are at /v0/topstories and /v0/newstories.
#
# Таким образом, при сборе данных с помощью API нельзя извлечь более 500 последних публикаций. Та же история с используемым враппером. Попытаемся достать больше 500 постов --- скажем, 1000.

# %%
new = hn.new_stories(1000)

# %%
len(new)
# Out:
# 500

# %% [markdown]
# Видно, что по запросу 1000 постов выдалось всего 500. Значит, к сожалению, вместо данных за последние полгода придется довольствоваться публикациями чуть больше, чем за последние сутки.

# %%
# creating dataframe for the parsed data
columns = ['id', 'title', 'date', 'url', 'comments', 'likes']
df = pd.DataFrame(columns=columns)

# %%
start_time = time.time()
for s in new:
    # getting item by id
    item = hn.get_item(s)
    print('\rProcessing item {}, {} of {} ({}% completed)'.format(
                s, new.index(s) + 1, len(new),
                round((new.index(s) + 1) / len(new) * 100, 2)), end='')
    # all comments are going to be stored in the list
    comments = []
    # checking for comments
    if item.descendants > 0:
        # collecting comments
        for k in item.kids:
            c = hn.get_item(k).text
            comments.append(c)
    # adding new row to the existing dataframe with all gathered information
    df.loc[len(df)] = [str(s), item.title, item.submission_time, item.url, comments, int(item.score)]
print('\nTime spent: {} minutes'.format(round((time.time() - start_time) / 60, 2)))
# Out:
# Processing item 15422989, 500 of 500 (100.0% completed)
# Time spent: 3.99 minutes

# %%
df['likes'] = df['likes'].astype(int)

# %%
df.head()
# Out:
#          id                                              title  \
# 0  15427629  Type Safety, ORM and Dependency Injection with...
# 1  15427621         Get Ahead in Tech… by Reading on Saturdays
# 2  15427607  Comparing the Performance Between Native iOS (...
# 3  15427604             Origins and History of Unix, 1969-1995
# 4  15427601  New Earbuds by Google Translates 40 Languages ...
#
#                  date                                                url  \
# 0 2017-10-08 12:55:27  http://paulosuzart.github.io/blog/2017/10/04/t...
# 1 2017-10-08 12:52:46  https://hackernoon.com/get-ahead-in-tech-by-re...
# 2 2017-10-08 12:49:15  https://www.codementor.io/jcalderaio/comparing...
# 3 2017-10-08 12:47:38  http://www.catb.org/esr/writings/taoup/html/ch...
# 4 2017-10-08 12:46:09  http://guardian.ng/life/whatsnew/new-earbuds-b...
#
#                                             comments  likes
# 0  [The syntax for the ORM definition and the rel...      2
# 1                                                 []      1
# 2                                                 []      1
# 3                                                 []      1
# 4       [Things are getting closer to black mirror.]      4

# %%
df.tail()
# Out:
#            id                                              title  \
# 495  15423032  We should talk about gun control vs. I’m going...
# 496  15423027  Physics, Topology, Logic and Computation: A Ro...
# 497  15423017  Angular News – Sharing Top Content from the An...
# 498  15422995       Show HN: Generate avatars from user initials
# 499  15422989  Ask HN: If the world were flat would it have o...
#
#                    date                                                url  \
# 495 2017-10-07 12:21:47  https://www.duffelblog.com/2017/10/gun-control...
# 496 2017-10-07 12:19:48                    https://arxiv.org/abs/0903.0340
# 497 2017-10-07 12:15:18  https://angular.jsnews.io/?utm_source=social&u...
# 498 2017-10-07 12:05:12                             https://ui-avatars.com
# 499 2017-10-07 12:03:55                                               None
#
#                                               comments  likes
# 495                                                 []      2
# 496  [John Baez is a fantastic writer. His home pag...    129
# 497                                                 []      1
# 498  [Two of my favorite avatar generators:<p><a hr...    158
# 499                                                 []      1

# %% [markdown]
# # 3. Обход внешних ссылок

# %% [markdown]
# После сбора данных был написан краулер, переходящий по всем найденным внешним ссылкам. Для получения содержимого страницы использовался модуль requests (https://github.com/requests/requests). В процессе обхода каждая рассматриваемая страница сохранялась в виде текстового сообщения с помощью инструмента readability (https://github.com/buriy/python-readability).

# %%
# crawler function
def url2text(url):
    # checking for url presence in the news post
    if url:
        # try-except construction here because some websites are restricted and have limited access
        try:
            # gaining url content
            response = requests.get(url)
            # building a etree document out of html
            doc = Document(response.text)
            # returning cleaned up content
            return doc.summary()
        except:
            return '.'
    else:
        return ''

# %%
start_time = time.time()
df['url_summary'] = df['url'].apply(lambda u: url2text(u))
print('\nTime spent: {} minutes'.format(round((time.time() - start_time) / 60, 2)))
# Out:
# c:\programdata\anaconda3\lib\site-packages\requests\packages\urllib3\connection.py:340: SubjectAltNameWarning: Certificate for images.guide has no `subjectAltName`, falling back to check for a `commonName` for now. This feature is being removed by major browsers and deprecated by RFC 2818. (See https://github.com/shazow/urllib3/issues/497 for details.)
#   SubjectAltNameWarning
# Time spent: 12.41 minutes

# %%
df.head()
# Out:
#          id                                              title  \
# 0  15427629  Type Safety, ORM and Dependency Injection with...
# 1  15427621         Get Ahead in Tech… by Reading on Saturdays
# 2  15427607  Comparing the Performance Between Native iOS (...
# 3  15427604             Origins and History of Unix, 1969-1995
# 4  15427601  New Earbuds by Google Translates 40 Languages ...
#
#                  date                                                url  \
# 0 2017-10-08 12:55:27  http://paulosuzart.github.io/blog/2017/10/04/t...
# 1 2017-10-08 12:52:46  https://hackernoon.com/get-ahead-in-tech-by-re...
# 2 2017-10-08 12:49:15  https://www.codementor.io/jcalderaio/comparing...
# 3 2017-10-08 12:47:38  http://www.catb.org/esr/writings/taoup/html/ch...
# 4 2017-10-08 12:46:09  http://guardian.ng/life/whatsnew/new-earbuds-b...
#
#                                             comments  likes  \
# 0  [The syntax for the ORM definition and the rel...      2
# 1                                                 []      1
# 2                                                 []      1
# 3                                                 []      1
# 4       [Things are getting closer to black mirror.]      4
#
#                                          url_summary
# 0  <html><body><div><article class="post-content"...
# 1  <html><body><div><div class="section-inner sec...
# 2  <html><body><div><div class="article__content"...
# 3  <html><body><div><div class="sect1" lang="en">...
# 4  <html><body><div><article data-post-type="post...

# %%
df.tail()
# Out:
#            id                                              title  \
# 495  15423032  We should talk about gun control vs. I’m going...
# 496  15423027  Physics, Topology, Logic and Computation: A Ro...
# 497  15423017  Angular News – Sharing Top Content from the An...
# 498  15422995       Show HN: Generate avatars from user initials
# 499  15422989  Ask HN: If the world were flat would it have o...
#
#                    date                                                url  \
# 495 2017-10-07 12:21:47  https://www.duffelblog.com/2017/10/gun-control...
# 496 2017-10-07 12:19:48                    https://arxiv.org/abs/0903.0340
# 497 2017-10-07 12:15:18  https://angular.jsnews.io/?utm_source=social&u...
# 498 2017-10-07 12:05:12                             https://ui-avatars.com
# 499 2017-10-07 12:03:55                                               None
#
#                                               comments  likes  \
# 495                                                 []      2
# 496  [John Baez is a fantastic writer. His home pag...    129
# 497                                                 []      1
# 498  [Two of my favorite avatar generators:<p><a hr...    158
# 499                                                 []      1
#
#                                            url_summary
# 495  <body id="readabilityBody">\n<center><h1>403 F...
# 496  <html><body><div><div class="dateline"><p>(Sub...
# 497  <html><body><div><div class="listing listing-b...
# 498  <html><body><div><div class="container">\n\t\t...
# 499

# %% [markdown]
# В процессе сбора данных некоторые ссылки не были обработаны, как, например, указанная ниже — в силу того, что социальная сеть LinkedIn на данный момент заблокирована на территории РФ.

# %%
url2text('https://www.linkedin.com/pulse/how-we-built-managed-full-mesh-transit-vpc-vpn-aws-sascha-coldewey/')
# Out:
# '.'

# %% [markdown]
# Подобных случаев было 7. Также в 30 постах не было найдено внешних ссылок, ибо, как видно из нижней строки полученной таблицы, в выборку попали посты типа Ask HN, содержащие в себе не новости, а вопросы, которые пользователи задавали комьюнити. Ссылки там на что-либо, соответственно, отсутствовали.

# %%
df['url_summary'].value_counts()[''], df['url_summary'].value_counts()['.']
# Out:
# (30, 7)

# %% [markdown]
# # 4. Фильтрация сообщений по бренду

# %% [markdown]
# После получения сообщений из них были выделены те, в которых упоминается Youtube. Данный бренд был выбран ввиду своей популярности на основе данных за прошлый год от компании Infegy, занимающейся мониторингом и анализом различных социальных медиа (https://top50.infegy.com/).

# %%
start_time = time.time()
df['youtube'] = df['url_summary'].apply(lambda u: 'youtube' in u.lower())
print('Time spent: {} minutes'.format(round((time.time() - start_time) / 60, 2)))
# Out:
# Time spent: 0.0 minutes

# %%
df.head()
# Out:
#          id                                              title  \
# 0  15427629  Type Safety, ORM and Dependency Injection with...
# 1  15427621         Get Ahead in Tech… by Reading on Saturdays
# 2  15427607  Comparing the Performance Between Native iOS (...
# 3  15427604             Origins and History of Unix, 1969-1995
# 4  15427601  New Earbuds by Google Translates 40 Languages ...
#
#                  date                                                url  \
# 0 2017-10-08 12:55:27  http://paulosuzart.github.io/blog/2017/10/04/t...
# 1 2017-10-08 12:52:46  https://hackernoon.com/get-ahead-in-tech-by-re...
# 2 2017-10-08 12:49:15  https://www.codementor.io/jcalderaio/comparing...
# 3 2017-10-08 12:47:38  http://www.catb.org/esr/writings/taoup/html/ch...
# 4 2017-10-08 12:46:09  http://guardian.ng/life/whatsnew/new-earbuds-b...
#
#                                             comments  likes  \
# 0  [The syntax for the ORM definition and the rel...      2
# 1                                                 []      1
# 2                                                 []      1
# 3                                                 []      1
# 4       [Things are getting closer to black mirror.]      4
#
#                                          url_summary youtube
# 0  <html><body><div><article class="post-content"...   False
# 1  <html><body><div><div class="section-inner sec...   False
# 2  <html><body><div><div class="article__content"...   False
# 3  <html><body><div><div class="sect1" lang="en">...   False
# 4  <html><body><div><article data-post-type="post...    True

# %%
df.tail()
# Out:
#            id                                              title  \
# 495  15423032  We should talk about gun control vs. I’m going...
# 496  15423027  Physics, Topology, Logic and Computation: A Ro...
# 497  15423017  Angular News – Sharing Top Content from the An...
# 498  15422995       Show HN: Generate avatars from user initials
# 499  15422989  Ask HN: If the world were flat would it have o...
#
#                    date                                                url  \
# 495 2017-10-07 12:21:47  https://www.duffelblog.com/2017/10/gun-control...
# 496 2017-10-07 12:19:48                    https://arxiv.org/abs/0903.0340
# 497 2017-10-07 12:15:18  https://angular.jsnews.io/?utm_source=social&u...
# 498 2017-10-07 12:05:12                             https://ui-avatars.com
# 499 2017-10-07 12:03:55                                               None
#
#                                               comments  likes  \
# 495                                                 []      2
# 496  [John Baez is a fantastic writer. His home pag...    129
# 497                                                 []      1
# 498  [Two of my favorite avatar generators:<p><a hr...    158
# 499                                                 []      1
#
#                                            url_summary youtube
# 495  <body id="readabilityBody">\n<center><h1>403 F...   False
# 496  <html><body><div><div class="dateline"><p>(Sub...   False
# 497  <html><body><div><div class="listing listing-b...    True
# 498  <html><body><div><div class="container">\n\t\t...   False
# 499                                                      False

# %%
df['youtube'].value_counts()
# Out:
# False    454
# True      46
# Name: youtube, dtype: int64

# %% [markdown]
# 46 из 500 последних постов содержат внешние ссылки на страницы, в тексте которых упоминается Youtube.

# %%
df.to_csv('hn_newest.csv')

# %% [markdown]
# # 5. Краткий анализ полученного корпуса

# %% [markdown]
# ## 5.1. Количество постов

# %%
# selecting posts with internal links containing 'youtube'
data = df[df['youtube'] == True].drop('youtube', axis=1)

# %%
len(data)
# Out:
# 46

# %% [markdown]
# Итак, в собранном корпусе 46 постов.

# %%
data
# Out:
#            id                                              title  \
# 4    15427601  New Earbuds by Google Translates 40 Languages ...
# 7    15427592  Believer's Voice of Victory Network Live Strea...
# 8    15427584                          Inside the internet rehab
# 9    15427581              New digital music platform for Afrika
# 14   15427526  How to fail in a coding interview which you ca...
# 16   15427497          Advice for New and Junior Data Scientists
# 45   15427322              Should Cognitect Do More for Clojure?
# 56   15427211  9 things that I learnt from the most successfu...
# 64   15427161  Unreal Engine Improvements for Fortnite: Battl...
# 70   15427124                  StackOverflow Architecture (2016)
# 206                                                 []      2
# 218                                                 []      2
# 223                                                 []      1
# 229                                                 []      3
# 251                                                 []      4
# 275                                                 []      2
# 279  [The actual title was &quot;Dear Google, in De...      3
# 282                                                 []      1
# 297                                                 []      2
# 308  [The article starts with discussing the top of...      2
# 310                                                 []      1
# 311                                                 []      2
# 323                                                 []      1
# 330                                                 []      1
# 338                                                 []      2
# 362  [This is quite similar to the &quot;Lenny&quot...     18
# 368  [Despite the title, the <i>very first sentence...      1
# 379                                                 []      2
# 385                                                 []      3
# 403                                                 []      2
# 411                                                 []      1
# 436                                                 []      1
# 458  [Robert Lustig has written an excellent book o...     15
# 461                                                 []      1
# 475  [This seems like a good time to mention Captai...    126
# 477                                                 []      1
# 497                                                 []      1
#
#                                            url_summary
# 4    <html><body><div><article data-post-type="post...
# 7    <html><body><div><div class="post-body entry-c...
# 8    <html><body><div><div class="content__article-...
# 9    <html><body><div><div class="post-content inne...
# 14   <html><body><div><div class="section-inner sec...
# 16   <html><body><div><div class="section-inner sec...
# 45   <html><body><div><article class="article">\n  ...
# 56   <html><body><div><div class="section-inner sec...
# 64   <html><body><div><div class="blog-header-info"...
# 70   <html><body><div><article class="post-content"...
# 72   <html><body><div><div class="article-entry tex...
# 79   <html><body><div><div class="post-body entry-c...
# 97   <html><body><div><div class="article">\n      ...
# 104  <html><body><div><div class="entry-content">&#...
# 111  <html><body><div><div class="video-body-text">...
# 117  <html><body><div><div class="group" itemprop="...
# 178  <html><body><div><div class="e-content">\n    ...
# 191  <html><body><div><div class="mw-parser-output"...
# 199  <html><body><div><div class="content__article-...
# 206  <html><body><div><div class="post-content"><p>...
# 218  <html><body><div><div class="content__article-...
# 223  <html><body><div><div class="post">\n  <h1 cla...
# 229  <html><body><div><div class="post-content entr...
# 251  <html><body><div><div class="bbp-reply-entry">...
# 275  <html><body><div><div class="post__content wys...
# 279  <html><body><div><div class="section-inner sec...
# 282  <html><body><div><div class="post-content modu...
# 297  <html><body><div><div class="post-content entr...
# 308  <html><body><div><article>\n      <p>The deman...
# 310  <html><body><div><p>The Debian project is plea...
# 311  <html><body><div><div data-reactid="245"><sect...
# 323  <html><body><div><div class="post-body entry-c...
# 330  <html><body><div><div class="article-content">...
# 338  <html><body><div><div class="text-wrapper" ite...
# 362  <html><body><div><div id="page-container" clas...
# 368  <html><body><div><div class="section-inner sec...
# 379  <html><body><div><section class="article-conte...
# 385  <html><body><div><div class="entry-content">\n...
# 403  <html><body><div><div class="post-body entry-c...
# 411  <html><body><div><div id="watch-description-te...
# 436  <html><body><div><body class="homepage" id="re...
# 458  <html><body><div><div class="content__article-...
# 461  <html><body><div><div class="article__body"><p...
# 475  <html><body><div><div class="content no-headin...
# 477  <html><body><div><div class="post-body" itempr...
# 497  <html><body><div><div class="listing listing-b...

# %%
data.to_csv('hn_newest_youtube.csv')

# %%
#data = pd.read_csv('hn_newest_youtube.csv', encoding='cp1251')

# %% [markdown]
# ## 5.2. Определение источников

# %% [markdown]
# Для того, чтобы определить, из каких источников собран корпус, использовался модуль urlparse (https://docs.python.org/3/library/urllib.parse.html), позволяющий выделить из URL доменное имя.

# %%
data_urls = []
for u in data['url']:
    data_urls.append('{uri.scheme}://{uri.netloc}/'.format(uri=urlparse(u)))

# %%
for u in sorted(list(set(data_urls))):
    print(u)
# Out:
# http://antrikshy.com/
# http://blog.cleancoder.com/
# http://evonomics.com/
# http://guardian.ng/
# http://highexistence.com/
# http://jjjvirtual7.blogspot.com/
# http://jollyrogertelephone.com/
# http://mashable.com/
# http://robert.ocallahan.org/
# http://www.independent.co.uk/
# http://www.lispcast.com/
# http://www.macdrifter.com/
# https://9to5google.com/
# https://angular.jsnews.io/
# https://bastianallgeier.com/
# https://cryptoinsider.com/
# https://en.wikipedia.org/
# https://gizmodo.com/
# https://hackernoon.com/
# https://m.signalvnoise.com/
# https://medium.com/
# https://millcomputing.com/
# https://motherboard.vice.com/
# https://nickcraver.com/
# https://techcrunch.com/
# https://terminalsare.sexy/
# https://www.cnbc.com/
# https://www.currentaffairs.org/
# https://www.debian.org/
# https://www.iafrikan.com/
# https://www.nature.com/
# https://www.newscientist.com/
# https://www.quantamagazine.org/
# https://www.raspberrypi.org/
# https://www.realclearpolitics.com/
# https://www.theguardian.com/
# https://www.unrealengine.com/
# https://www.wired.com/
# https://www.youtube.com/

# %% [markdown]
# ## 5.3. Определение наиболее частых слов

# %% [markdown]
# Чтобы проверить, какие слова (за исключением стоп-слов) встречаются в полученном корпусе чаще всего, из сообщений сначала с помощью регулярных выражений были удалены все ненужные символы, полученные тексты были объединены в один большой, в котором после этого с помощью библиотеки nltk была рассчитана частота встречаемости каждого слова.

# %%
# function for removal unnecessary stuff from page content
def html_stripper(text):
    # deleting html-tags with regular expression
    text = re.sub('<[^<]+?>', '', str(text))
    # substituting all whitespaces, hyphens and dashes with simple whitespace
    text = re.sub('[\s-]', ' ', text)
    return text

# %%
# stripping data into one text
stripped_data = ' '.join([html_stripper(s) for s in data['url_summary']])

# %%
stripped_data[:200]
# Out:
# '    Google has finally achieved what science fiction novels (and various fundraiser campaigns) have been promising us for years: a universal translator which could close linguistic barriers between na'

# %%
# regular expression for identifying words
prog = re.compile('[A-Za-z]+')
l = [w for w in prog.findall(stripped_data.lower()) if not w in stop_words]
d = FreqDist(l)
print(d)
print(d.most_common(30))
# Out:
# <FreqDist with 9350 samples and 43721 outcomes>
# [('people', 237), ('like', 230), ('one', 194), ('would', 175), ('time', 159), ('think', 151), ('says', 149), ('google', 146), ('new', 141), ('make', 129), ('also', 126), ('world', 119), ('get', 114), ('star', 114), ('even', 111), ('may', 111), ('way', 108), ('use', 106), ('could', 104), ('know', 101), ('many', 100), ('us', 97), ('work', 97), ('data', 91), ('first', 91), ('things', 91), ('years', 88), ('see', 88), ('every', 86), ('want', 82)]

# %% [markdown]
# ## 5.4. Классификация источников по новостным и не новостным

# %% [markdown]
# Завершающим этапом анализа и самого проекта в целом была классификация источников по блогам и новостным изданиям и по всему остальному.

# %% [markdown]
# - http://antrikshy.com/
# Не новости
# - http://blog.cleancoder.com/
# Блог
# - http://evonomics.com/
# Новости
# - http://guardian.ng/
# Новости
# - http://highexistence.com/
# Блог
# - http://jjjvirtual7.blogspot.com/
# Блог
# - http://jollyrogertelephone.com/
# Не новости
# - http://mashable.com/
# Новости
# - http://robert.ocallahan.org/
# Блог
# - http://www.independent.co.uk/
# Новости
# - http://www.lispcast.com/
# Блог
# - http://www.macdrifter.com/
# Блог
# - https://9to5google.com/
# Новости
# - https://angular.jsnews.io/
# Новости
# - https://bastianallgeier.com/
# Блог
# - https://cryptoinsider.com/
# Новости
# - https://en.wikipedia.org/
# Не новости
# - https://gizmodo.com/
# Блог
# - https://hackernoon.com/
# Новости
# - https://m.signalvnoise.com/
# Блог
# - https://medium.com/
# Новости
# - https://millcomputing.com/
# Новости
# - https://motherboard.vice.com/
# Новости
# - https://nickcraver.com/
# Блог
# - https://techcrunch.com/
# Новости
# - https://terminalsare.sexy/
# Не новости
# - https://www.cnbc.com/
# Новости
# - https://www.currentaffairs.org/
# Новости
# - https://www.debian.org/
# Не новости
# - https://www.iafrikan.com/
# Новости
# - https://www.nature.com/
# Новости
# - https://www.newscientist.com/
# Новости
# - https://www.quantamagazine.org/
# Блог
# - https://www.raspberrypi.org/
# Блог
# - https://www.realclearpolitics.com/
# Новости
# - https://www.theguardian.com/
# Новости
# - https://www.unrealengine.com/
# Не новости
# - https://www.wired.com/
# Новости
# - https://www.youtube.com/
# Не новости

# %% [markdown]
# Итак, из 39 выявленных источников 12 являются блогами, 20 — новостные издания, а оставшиеся 7 ничем из упомянутого не являются. Добавим полученную информацию к полученному датасету (ссылкам на блоги и новостные издания поставим в соответствие значение '1', остальным - '0').

# %%
not_news = ['http://antrikshy.com/', 'http://jollyrogertelephone.com/', 'https://en.wikipedia.org/',
            'https://terminalsare.sexy/', 'https://www.debian.org/', 'https://www.unrealengine.com/', 'https://www.youtube.com/']
data['url_news'] = data['url'].apply(lambda u:
                                     1 if '{uri.scheme}://{uri.netloc}/'.format(uri=urlparse(u)) not in not_news else 0)

# %%
data
# Out:
#     Unnamed: 0        id                                              title  \
# 0            4  15427601  New Earbuds by Google Translates 40 Languages ...
# 1            7  15427592  Believer's Voice of Victory Network Live Strea...
# 2            8  15427584                          Inside the internet rehab
# 3            9  15427581              New digital music platform for Afrika
# 4           14  15427526  How to fail in a coding interview which you ca...
# 5           16  15427497          Advice for New and Junior Data Scientists
# 6           45  15427322              Should Cognitect Do More for Clojure?
# 7           56  15427211  9 things that I learnt from the most successfu...
# 8           64  15427161  Unreal Engine Improvements for Fortnite: Battl...
# 9           70  15427124                  StackOverflow Architecture (2016)
# 10          72  15427108                         The new electric utilities
# 11          79  15426983       Thoughts on Microsoft's Time-Travel Debugger
# 12          97  15426782  Artificial Intelligence, Super Computers, and ...
# 13         104  15426670       Concentrated Wealth Is Strangling Prosperity
# 14         111  15426617               Camille Paglia vs. Identity Politics
# 15         117  15426545              How Bill Gates and Warren Buffett met
# 16         178  15425858                              Bullet Journal (2016)
# 17         191  15425718                                        KIC 8462852
# 18         199  15425656  Google CEO Sundar Pichai: 'I don't know whethe...
# 19         206  15425612     Undercover at the Bullshit Factory (Dan Lyons)
# 20         218  15425454   The tech insiders who fear a smartphone dystopia
# 35  ['Despite the title, the <i>very first sentenc...      1
# 36                                                 []      2
# 37                                                 []      3
# 38                                                 []      2
# 39                                                 []      1
# 40                                                 []      1
# 41  ['Robert Lustig has written an excellent book ...     15
# 42                                                 []      1
# 43  ['This seems like a good time to mention Capta...    126
# 44                                                 []      1
# 45                                                 []      1
#
#                                           url_summary  url_news
# 0   <html><body><div><article data-post-type="post...         1
# 1   <html><body><div><div class="post-body entry-c...         1
# 2   <html><body><div><div class="content__article-...         1
# 3   <html><body><div><div class="post-content inne...         1
# 4   <html><body><div><div class="section-inner sec...         1
# 5   <html><body><div><div class="section-inner sec...         1
# 6   <html><body><div><article class="article">\r\n...         1
# 7   <html><body><div><div class="section-inner sec...         1
# 8   <html><body><div><div class="blog-header-info"...         0
# 9   <html><body><div><article class="post-content"...         1
# 10  <html><body><div><div class="article-entry tex...         1
# 11  <html><body><div><div class="post-body entry-c...         1
# 12  <html><body><div><div class="article">\r\n    ...         1
# 13  <html><body><div><div class="entry-content">&#...         1
# 14  <html><body><div><div class="video-body-text">...         1
# 15  <html><body><div><div class="group" itemprop="...         1
# 16  <html><body><div><div class="e-content">\r\n  ...         1
# 17  <html><body><div><div class="mw-parser-output"...         0
# 18  <html><body><div><div class="content__article-...         1
# 19  <html><body><div><div class="post-content"><p>...         1
# 20  <html><body><div><div class="content__article-...         1
# 21  <html><body><div><div class="post">\r\n  <h1 c...         0
# 22  <html><body><div><div class="post-content entr...         1
# 23  <html><body><div><div class="bbp-reply-entry">...         1
# 24  <html><body><div><div class="post__content wys...         1
# 25  <html><body><div><div class="section-inner sec...         1
# 26  <html><body><div><div class="post-content modu...         1
# 27  <html><body><div><div class="post-content entr...         1
# 28  <html><body><div><article>\r\n      <p>The dem...         1
# 29  <html><body><div><p>The Debian project is plea...         0
# 30  <html><body><div><div data-reactid="245"><sect...         1
# 31  <html><body><div><div class="post-body entry-c...         1
# 32  <html><body><div><div class="article-content">...         1
# 33  <html><body><div><div class="text-wrapper" ite...         1
# 34  <html><body><div><div id="page-container" clas...         0
# 35  <html><body><div><div class="section-inner sec...         1
# 36  <html><body><div><section class="article-conte...         1
# 37  <html><body><div><div class="entry-content">\r...         1
# 38  <html><body><div><div class="post-body entry-c...         1
# 39  <html><body><div><div id="watch-description-te...         0
# 40  <html><body><div><body class="homepage" id="re...         0
# 41  <html><body><div><div class="content__article-...         1
# 42  <html><body><div><div class="article__body"><p...         1
# 43  <html><body><div><div class="content no-headin...         1
# 44  <html><body><div><div class="post-body" itempr...         1
# 45  <html><body><div><div class="listing listing-b...         1

# %%
data['url_news'].value_counts()
# Out:
# 1    39
# 0     7
# Name: url_news, dtype: int64

# %% [markdown]
# Итак, из 46 собранных ссылок 39 ведут на блоги и новостные издания, а остальные — на неновостные издания.

# %%
data.to_csv('hn_newest_youtube.csv')

# %% [markdown]
# # 6. Заключение

# %% [markdown]
# В рамках данного проекта с сайта https://news.ycombinator.com/ были собраны последние посты при использовании официального API, написан краулер для обхода внешних ссылок, полученные страницы сохранены как текстовые сообщения, а затем отфильтрованы по упоминанию выбранного бренда. После этого был произведен краткий анализ собранного корпуса.
